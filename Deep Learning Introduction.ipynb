# %% [markdown]
# ## Introduction
# This is an introduction to building a neural network in Python.
#
# In this code I follow this [example](https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/) available at Machine Learning Mastery site

# %%
# load modules
import pandas as pd
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# load data
# add columns from description
data = pd.read_csv("https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv",
                   header=None,names=['times_pregnant','plasma_glucose_concentration',
                                      'diastolic_bp_mmhg','tricep_skin_thickness','2_hour_serum_insulin',
                                     'bmi','diabetes_pedigree','age','class'])

# %%
# check top 5 rows
data.head()
# Out:
#    times_pregnant  plasma_glucose_concentration  diastolic_bp_mmhg  \
# 0               6                           148                 72
# 1               1                            85                 66
# 2               8                           183                 64
# 3               1                            89                 66
# 4               0                           137                 40
#
#    tricep_skin_thickness  2_hour_serum_insulin   bmi  diabetes_pedigree  age  \
# 0                     35                     0  33.6              0.627   50
# 1                     29                     0  26.6              0.351   31
# 2                      0                     0  23.3              0.672   32
# 3                     23                    94  28.1              0.167   21
# 4                     35                   168  43.1              2.288   33
#
#    class
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1

# %%
# get data overview
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   times_pregnant                768 non-null    int64
#  1   plasma_glucose_concentration  768 non-null    int64
#  2   diastolic_bp_mmhg             768 non-null    int64
#  3   tricep_skin_thickness         768 non-null    int64
#  4   2_hour_serum_insulin          768 non-null    int64
#  5   bmi                           768 non-null    float64
#  6   diabetes_pedigree             768 non-null    float64
#  7   age                           768 non-null    int64
#  8   class                         768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# data summary
data.describe()
# Out:
#        times_pregnant  plasma_glucose_concentration  diastolic_bp_mmhg  \
# count      768.000000                    768.000000         768.000000
# mean         3.845052                    120.894531          69.105469
# std          3.369578                     31.972618          19.355807
# min          0.000000                      0.000000           0.000000
# 25%          1.000000                     99.000000          62.000000
# 50%          3.000000                    117.000000          72.000000
# 75%          6.000000                    140.250000          80.000000
# max         17.000000                    199.000000         122.000000
#
#        tricep_skin_thickness  2_hour_serum_insulin         bmi  \
# count             768.000000            768.000000  768.000000
# mean               20.536458             79.799479   31.992578
# std                15.952218            115.244002    7.884160
# min                 0.000000              0.000000    0.000000
# ...
